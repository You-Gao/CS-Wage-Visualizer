# %%
import requests
import pandas as pd
import os
import sys

# %%
# Senior Role String Identifiers
senior_roles = ['senior', 'sr', 'lead', 'principal', 'staff', 'director', 'head', 'chief', 'vp', 'cto', 'cfo', 'cio', 'coo', 'ceo', 'president', 'founder', 'partner', 'executive', 'expert', 'guru']

# Numbered Roles for Seniority
seniority = [ 'III', 'IV', 'V', 'VI', 'VII', 'VIII', 'IX', 'X', 3, 4, 5, 6, 7, 8, 9, 10]
seniority = [str(x) for x in seniority]

# %%
# site https://h1bdata.info/index.php?em=&job=[job]&city=&year=2023
def get_data(job, year):
    url = f'https://h1bdata.info/index.php?em=&job={job}&city=&year={year}'
    response = requests.get(url)
    return response.text

def process_data(data):
    data = data.split('<table border="1" id="myTable" class="tablesorter tablesorter-blue hasStickyHeaders">')[1]
    data = data.split('</table>')[0]
    data = data.split('<tr>')
    data = data[1:]
    data = [x.split('</td>') for x in data]
    data = [[x.split('<td>') for x in y] for y in data]
    data = [[x[1] for x in y if len(x) > 1] for y in data]
    data = [[x.replace('<a href="', '').replace('">', ' ').replace('</a>', '') for x in y] for y in data]
    return data

def extract_data(data, year):
    table = []
    for row in data[1:]:
        try:
            company = row[0][row[0].find(str(year)) + 5:]
            job = row[1][row[1].find(str(year)) + 5:]
            salary = row[2][row[2].find("_blank") + 7:]
            location = row[3][row[3].find(str(year)) + 5:]
            year = year
            if any(x in job.lower() for x in senior_roles) or any(x in job for x in seniority):
                continue
            table.append([company, job, salary, location, year])
        except Exception as e:
            print(row)
            continue

    return table

def table_to_dataframe(data):
    df = pd.DataFrame(data, columns=['Company', 'Job', 'Salary', 'Location', 'Year'])
    return df

# %%
jobx = 'data+scientist'
year = 2023
data = get_data(jobx, year)
data = process_data(data)
data = extract_data(data, year)
df = table_to_dataframe(data)
print(df)
# Out:
# []
# []
# []
# []
# []
#                    Company             Job   Salary        Location  Year
# 0       ISTEAM ACADEMY INC  DATA SCIENTIST   56,000  BURLINGTON, MA  2023
# 1     UNIHOME NEW YORK INC  DATA SCIENTIST   57,440        TROY, MI  2023
# 2         LINEAR STATS INC  DATA SCIENTIST   58,000   CHAMPAIGN, IL  2023
# 3         LINEAR STATS INC  DATA SCIENTIST   60,000   CHAMPAIGN, IL  2023
# 4         LINEAR STATS INC  DATA SCIENTIST   60,000   CHAMPAIGN, IL  2023
# ...                    ...             ...      ...             ...   ...
# 2214         BYTEDANCE INC  DATA SCIENTIST  315,000    SAN JOSE, CA  2023
# 2215               USG INC  DATA SCIENTIST  910,000      DULUTH, GA  2023
# 2216               USG INC  DATA SCIENTIST  910,000      DULUTH, GA  2023
# 2217               USG INC  DATA SCIENTIST  910,000      DULUTH, GA  2023
# 2218               USG INC  DATA SCIENTIST  910,000      DULUTH, GA  2023
#
# [2219 rows x 5 columns]

# %%
with open('jobs_to_scrape.txt', 'r') as f:
    jobs = f.readlines()
    jobs = [x.strip() for x in jobs]

jobs_to_scrape = []
for row in jobs:
    data = row.split(':')
    name = data[0]
    print(name)
    data = data[1].split(',')
    exclude = [x[1:] for x in data if x[0] == '-']
    include = [x for x in data if x[0] != '-']
    jobs_to_scrape.append([name, include, exclude])
# Out:
# Machine Learning
# Artifical Intelligence
# Data Science
# Data Analyst
# Data Engineer
# Graphics
# AR VR
# Deep Learning
# Cybersecurity Engineer
# Security Engineer
# Embedded Systems Engineer
# Full-Stack Developer
# Front-end Developer
# DevOps Engineer
# Cloud Architect
# Software Architect
# Data Architect
# Project Manager
# QA Engineer
# Mobile Developer

# %%
jobs_to_scrape
# Out:
# [['Machine Learning', ['machine learnin', 'ml'], []],
#  ['Artifical Intelligence',
#   ['artificial', 'ai'],
#   ['AIR', 'AIRCRAFT', 'AIRLINE', 'AIX', 'AIR QUALITY', 'AIRPORT']],
#  ['Data Science', ['data scien'], []],
#  ['Data Analyst', ['data ana'], []],
#  ['Data Engineer', ['data eng'], []],
#  ['Graphics',
#   ['gpu', 'graphics software engineer', 'graphics hardware engineer'],
#   []],
#  ['AR VR',
#   ['ar ', 'vr ', 'virtual reality', 'augmented'],
#   ['architect',
#    'arc',
#    'art',
#    'ara',
#    'area',
#    'archer',
#    'ariba',
#    'archivist',
#    'ARCHITECH',
#    'ARABIC',
#    'ARCHEOLOGIIST']],
#  ['Deep Learning', ['deep learnin'], []],
#  ['Cybersecurity Engineer', ['cyber'], []],
#  ['Security Engineer', ['security'], []],
#  ['Embedded Systems Engineer', ['embedded'], []],
#  ['Full-Stack Developer', ['full stac', 'web dev'], []],
#  ['Front-end Developer', ['front'], []],
#  ['DevOps Engineer', ['devop'], []],
#  ['Cloud Architect', ['cloud arc'], []],
#  ['Software Architect', ['software arc'], []],
#  ['Data Architect', ['data arc'], []],
#  ['Project Manager', ['scrum ma', 'scrum', 'agile pr'], []],
#  ['QA Engineer', ['testin', 'qa'], []],
#  ['Mobile Developer', ['mobile'], []]]

# %%
for i in range(2012, 2024):
    YEAR = i
    os.makedirs(f'data/{i}', exist_ok=True)
    for name, jobs, exclude in jobs_to_scrape:
        dfs = []
        for job in jobs:
            print(f'scraping {job}')
            data = get_data(job, YEAR)
            data = process_data(data)
            data = extract_data(data, YEAR)
            df = table_to_dataframe(data)
            for word in exclude:
                df = df[~df['Job'].str.contains(str.upper(word))]
            df['Salary'] = df['Salary'].str.replace(',', '').str.replace('$', '').astype(float)
            dfs.append(df)
        df = pd.concat(dfs)
        df.to_csv(f'data/{i}/{name}.csv', index=False)
        print(f'{name} done')
        print('-------------------')
    print(f'{YEAR} done')
# Out:
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2012 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2013 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2014 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# []
# Mobile Developer done
# -------------------
# 2015 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# []
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# scraping scrum
# []
# []
# []
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# []
# []
# []
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2016 done
# scraping machine learnin
# []
# []
# []
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# []
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# scraping scrum
# []
# []
# []
# []
# []
# []
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# []
# []
# []
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2017 done
# scraping machine learnin
# []
# []
# []
# []
# []
# []
# []
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# []
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# []
# []
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# []
# scraping scrum
# []
# []
# []
# []
# []
# []
# []
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# []
# []
# []
# []
# []
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2018 done
# scraping machine learnin
# []
# []
# []
# []
# []
# []
# []
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# []
# scraping graphics hardware engineer
# []
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# []
# []
# []
# []
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# []
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# []
# scraping scrum
# []
# []
# []
# []
# []
# []
# []
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# []
# []
# []
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2019 done
# scraping machine learnin
# []
# []
# []
# []
# []
# []
# []
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# []
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# []
# []
# []
# []
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# []
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# []
# scraping scrum
# []
# []
# []
# []
# []
# []
# []
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# []
# []
# scraping qa
# []
# []
# []
# []
# []
# []
# []
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2020 done
# scraping machine learnin
# []
# []
# []
# []
# []
# []
# []
# scraping ml
# []
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# []
# scraping graphics hardware engineer
# []
# []
# []
# []
# Graphics done
# -------------------
# scraping ar
# []
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# []
# []
# []
# []
# []
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# []
# []
# []
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# []
# scraping scrum
# []
# []
# []
# []
# []
# []
# []
# scraping agile pr
# []
# Project Manager done
# -------------------
# scraping testin
# []
# []
# scraping qa
# []
# []
# []
# []
# []
# []
# []
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2021 done
# scraping machine learnin
# []
# []
# []
# []
# []
# []
# []
# scraping ml
# []
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# []
# scraping graphics hardware engineer
# []
# []
# []
# []
# []
# Graphics done
# -------------------
# scraping ar
# []
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# []
# []
# []
# []
# []
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# []
# []
# []
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# []
# scraping scrum
# scraping agile pr
# []
# Project Manager done
# -------------------
# scraping testin
# []
# scraping qa
# []
# []
# []
# []
# []
# []
# []
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2022 done
# scraping machine learnin
# []
# []
# []
# []
# []
# []
# []
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# []
# scraping graphics software engineer
# scraping graphics hardware engineer
# []
# Graphics done
# -------------------
# scraping ar
# []
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# []
# []
# []
# []
# []
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# []
# []
# []
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# []
# scraping scrum
# []
# []
# []
# []
# []
# []
# []
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# []
# scraping qa
# []
# []
# []
# []
# []
# []
# []
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# Mobile Developer done
# -------------------
# 2023 done

# %%
# Summary Page
for year in os.listdir('data'):
    records = 0
    for file in os.listdir(f'data/{year}'):
        df = pd.read_csv(f'data/{year}/{file}')
        print(f'{file}: {df.shape[0]} records')
        records += df.shape[0]
    print(f'{year}: {records} records')
    print('-------------------')
# Out:
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 0 records
# Cloud Architect.csv: 0 records
# Cybersecurity Engineer.csv: 0 records
# Data Analyst.csv: 0 records
# Data Architect.csv: 0 records
# Data Engineer.csv: 0 records
# Data Science.csv: 0 records
# Deep Learning.csv: 0 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 0 records
# Front-end Developer.csv: 0 records
# Full-Stack Developer.csv: 0 records
# Graphics.csv: 0 records
# Machine Learning.csv: 0 records
# Mobile Developer.csv: 0 records
# Project Manager.csv: 0 records
# QA Engineer.csv: 0 records
# Security Engineer.csv: 0 records
# Software Architect.csv: 1 records
# 2012: 1 records
# -------------------
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 0 records
# Cloud Architect.csv: 0 records
# Cybersecurity Engineer.csv: 0 records
# Data Analyst.csv: 1 records
# Data Architect.csv: 2 records
# Data Engineer.csv: 3 records
# Data Science.csv: 1 records
# Deep Learning.csv: 0 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 0 records
# Front-end Developer.csv: 0 records
# Full-Stack Developer.csv: 0 records
# Graphics.csv: 2 records
# Machine Learning.csv: 1 records
# Mobile Developer.csv: 1 records
# Project Manager.csv: 0 records
# QA Engineer.csv: 2 records
# Security Engineer.csv: 2 records
# Software Architect.csv: 0 records
# 2013: 15 records
# -------------------
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 0 records
# Cloud Architect.csv: 0 records
# Cybersecurity Engineer.csv: 0 records
# Data Analyst.csv: 4 records
# Data Architect.csv: 1 records
# Data Engineer.csv: 2 records
# Data Science.csv: 3 records
# Deep Learning.csv: 0 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 2 records
# Front-end Developer.csv: 0 records
# Full-Stack Developer.csv: 0 records
# Graphics.csv: 1 records
# Machine Learning.csv: 0 records
# Mobile Developer.csv: 0 records
# Project Manager.csv: 0 records
# QA Engineer.csv: 6 records
# Security Engineer.csv: 4 records
# Software Architect.csv: 0 records
# 2014: 23 records
# -------------------
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 0 records
# Cloud Architect.csv: 1 records
# Cybersecurity Engineer.csv: 3 records
# Data Analyst.csv: 135 records
# Data Architect.csv: 33 records
# Data Engineer.csv: 69 records
# Data Science.csv: 120 records
# Deep Learning.csv: 0 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 34 records
# Front-end Developer.csv: 27 records
# Full-Stack Developer.csv: 8 records
# Graphics.csv: 53 records
# Machine Learning.csv: 7 records
# Mobile Developer.csv: 24 records
# Project Manager.csv: 35 records
# QA Engineer.csv: 12 records
# Security Engineer.csv: 43 records
# Software Architect.csv: 87 records
# 2015: 691 records
# -------------------
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 12 records
# Cloud Architect.csv: 26 records
# Cybersecurity Engineer.csv: 24 records
# Data Analyst.csv: 2033 records
# Data Architect.csv: 121 records
# Data Engineer.csv: 401 records
# Data Science.csv: 1101 records
# Deep Learning.csv: 1 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 248 records
# Front-end Developer.csv: 127 records
# Full-Stack Developer.csv: 73 records
# Graphics.csv: 96 records
# Machine Learning.csv: 40 records
# Mobile Developer.csv: 190 records
# Project Manager.csv: 264 records
# QA Engineer.csv: 78 records
# Security Engineer.csv: 259 records
# Software Architect.csv: 570 records
# 2016: 5664 records
# -------------------
# AR VR.csv: 7 records
# Artifical Intelligence.csv: 25 records
# Cloud Architect.csv: 26 records
# Cybersecurity Engineer.csv: 61 records
# Data Analyst.csv: 1779 records
# Data Architect.csv: 164 records
# Data Engineer.csv: 683 records
# Data Science.csv: 1602 records
# Deep Learning.csv: 12 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 300 records
# Front-end Developer.csv: 151 records
# Full-Stack Developer.csv: 78 records
# Graphics.csv: 128 records
# Machine Learning.csv: 114 records
# Mobile Developer.csv: 185 records
# Project Manager.csv: 406 records
# QA Engineer.csv: 83 records
# Security Engineer.csv: 372 records
# Software Architect.csv: 621 records
# 2017: 6797 records
# -------------------
# AR VR.csv: 9 records
# Artifical Intelligence.csv: 57 records
# Cloud Architect.csv: 48 records
# Cybersecurity Engineer.csv: 124 records
# Data Analyst.csv: 1905 records
# Data Architect.csv: 288 records
# Data Engineer.csv: 1125 records
# Data Science.csv: 2709 records
# Deep Learning.csv: 34 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 423 records
# Front-end Developer.csv: 161 records
# Full-Stack Developer.csv: 159 records
# Graphics.csv: 105 records
# Machine Learning.csv: 269 records
# Mobile Developer.csv: 181 records
# Project Manager.csv: 815 records
# QA Engineer.csv: 111 records
# Security Engineer.csv: 626 records
# Software Architect.csv: 840 records
# 2018: 9989 records
# -------------------
# AR VR.csv: 9 records
# Artifical Intelligence.csv: 125 records
# Cloud Architect.csv: 59 records
# Cybersecurity Engineer.csv: 182 records
# Data Analyst.csv: 2242 records
# Data Architect.csv: 343 records
# Data Engineer.csv: 1845 records
# Data Science.csv: 3715 records
# Deep Learning.csv: 29 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 528 records
# Front-end Developer.csv: 289 records
# Full-Stack Developer.csv: 241 records
# Graphics.csv: 110 records
# Machine Learning.csv: 547 records
# Mobile Developer.csv: 151 records
# Project Manager.csv: 895 records
# QA Engineer.csv: 74 records
# Security Engineer.csv: 683 records
# Software Architect.csv: 740 records
# 2019: 12807 records
# -------------------
# AR VR.csv: 8 records
# Artifical Intelligence.csv: 119 records
# Cloud Architect.csv: 65 records
# Cybersecurity Engineer.csv: 206 records
# Data Analyst.csv: 2078 records
# Data Architect.csv: 274 records
# Data Engineer.csv: 2713 records
# Data Science.csv: 4151 records
# Deep Learning.csv: 22 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 441 records
# Front-end Developer.csv: 313 records
# Full-Stack Developer.csv: 269 records
# Graphics.csv: 105 records
# Machine Learning.csv: 718 records
# Mobile Developer.csv: 124 records
# Project Manager.csv: 786 records
# QA Engineer.csv: 1709 records
# Security Engineer.csv: 683 records
# Software Architect.csv: 736 records
# 2020: 15520 records
# -------------------
# AR VR.csv: 9 records
# Artifical Intelligence.csv: 152 records
# Cloud Architect.csv: 97 records
# Cybersecurity Engineer.csv: 196 records
# Data Analyst.csv: 2437 records
# Data Architect.csv: 283 records
# Data Engineer.csv: 3873 records
# Data Science.csv: 4915 records
# Deep Learning.csv: 17 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 478 records
# Front-end Developer.csv: 379 records
# Full-Stack Developer.csv: 369 records
# Graphics.csv: 235 records
# Machine Learning.csv: 1026 records
# Mobile Developer.csv: 109 records
# Project Manager.csv: 916 records
# QA Engineer.csv: 1641 records
# Security Engineer.csv: 678 records
# Software Architect.csv: 638 records
# 2021: 18448 records
# -------------------
# AR VR.csv: 2 records
# Artifical Intelligence.csv: 140 records
# Cloud Architect.csv: 97 records
# Cybersecurity Engineer.csv: 253 records
# Data Analyst.csv: 2208 records
# Data Architect.csv: 224 records
# Data Engineer.csv: 4593 records
# Data Science.csv: 4707 records
# Deep Learning.csv: 16 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 393 records
# Front-end Developer.csv: 453 records
# Full-Stack Developer.csv: 359 records
# Graphics.csv: 288 records
# Machine Learning.csv: 1059 records
# Mobile Developer.csv: 101 records
# Project Manager.csv: 500 records
# QA Engineer.csv: 1581 records
# Security Engineer.csv: 780 records
# Software Architect.csv: 584 records
# 2022: 18338 records
# -------------------
# AR VR.csv: 8 records
# Artifical Intelligence.csv: 162 records
# Cloud Architect.csv: 122 records
# Cybersecurity Engineer.csv: 263 records
# Data Analyst.csv: 1810 records
# Data Architect.csv: 189 records
# Data Engineer.csv: 3673 records
# Data Science.csv: 3411 records
# Deep Learning.csv: 16 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 303 records
# Front-end Developer.csv: 290 records
# Full-Stack Developer.csv: 317 records
# Graphics.csv: 151 records
# Machine Learning.csv: 799 records
# Mobile Developer.csv: 42 records
# Project Manager.csv: 640 records
# QA Engineer.csv: 1314 records
# Security Engineer.csv: 575 records
# Software Architect.csv: 442 records
# 2023: 14527 records
# -------------------
