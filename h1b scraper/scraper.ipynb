# %%
import requests
import pandas as pd
import os

# %%
# site https://h1bdata.info/index.php?em=&job=[job]&city=&year=2023
def get_data(job, year):
    url = f'https://h1bdata.info/index.php?em=&job={job}&city=&year={year}'
    response = requests.get(url)
    return response.text

def process_data(data):
    data = data.split('<table border="1" id="myTable" class="tablesorter tablesorter-blue hasStickyHeaders">')[1]
    data = data.split('</table>')[0]
    data = data.split('<tr>')
    data = data[1:]
    data = [x.split('</td>') for x in data]
    data = [[x.split('<td>') for x in y] for y in data]
    data = [[x[1] for x in y if len(x) > 1] for y in data]
    data = [[x.replace('<a href="', '').replace('">', ' ').replace('</a>', '') for x in y] for y in data]
    return data

def extract_data(data, year):
    table = []
    for row in data[1:]:
        try:
            company = row[0][row[0].find(str(year)) + 5:]
            job = row[1][row[1].find(str(year)) + 5:]
            salary = row[2][row[2].find("_blank") + 7:]
            location = row[3][row[3].find(str(year)) + 5:]
            year = year
            table.append([company, job, salary, location, year])
        except:
            pass
    return table

def table_to_dataframe(data):
    df = pd.DataFrame(data, columns=['Company', 'Job', 'Salary', 'Location', 'Year'])
    return df

# %%
with open('jobs_to_scrape.txt', 'r') as f:
    jobs = f.readlines()
    jobs = [x.strip() for x in jobs]

jobs_to_scrape = []
for row in jobs:
    data = row.split(':')
    name = data[0]
    print(name)
    data = data[1].split(',')
    exclude = [x[1:] for x in data if x[0] == '-']
    include = [x for x in data if x[0] != '-']
    jobs_to_scrape.append([name, include, exclude])
# Out:
# Machine Learning
# Artifical Intelligence
# Data Science
# Data Analyst
# Data Engineer
# Graphics
# AR VR
# Deep Learning
# Cybersecurity Engineer
# Security Engineer
# Embedded Systems Engineer
# Full-Stack Developer
# Front-end Developer
# DevOps Engineer
# Cloud Architect
# Software Architect
# Data Architect
# Project Manager
# QA Engineer
# Mobile Developer

# %%
jobs_to_scrape
# Out:
# [['Machine Learning', ['machine learnin', 'ml'], []],
#  ['Artifical Intelligence',
#   ['artificial', 'ai'],
#   ['AIR', 'AIRCRAFT', 'AIRLINE', 'AIX', 'AIR QUALITY', 'AIRPORT']],
#  ['Data Science', ['data scien'], []],
#  ['Data Analyst', ['data ana'], []],
#  ['Data Engineer', ['data eng'], []],
#  ['Graphics',
#   ['gpu', 'graphics software engineer', 'graphics hardware engineer'],
#   []],
#  ['AR VR',
#   ['ar ', 'vr ', 'virtual reality', 'augmented'],
#   ['architect',
#    'arc',
#    'art',
#    'ara',
#    'area',
#    'archer',
#    'ariba',
#    'archivist',
#    'ARCHITECH',
#    'ARABIC',
#    'ARCHEOLOGIIST']],
#  ['Deep Learning', ['deep learnin'], []],
#  ['Cybersecurity Engineer', ['cyber'], []],
#  ['Security Engineer', ['security'], []],
#  ['Embedded Systems Engineer', ['embedded'], []],
#  ['Full-Stack Developer', ['full stac', 'web dev'], []],
#  ['Front-end Developer', ['front'], []],
#  ['DevOps Engineer', ['devop'], []],
#  ['Cloud Architect', ['cloud arc'], []],
#  ['Software Architect', ['software arc'], []],
#  ['Data Architect', ['data arc'], []],
#  ['Project Manager', ['scrum ma', 'scrum', 'agile pr'], []],
#  ['QA Engineer', ['testin', 'qa'], []],
#  ['Mobile Developer', ['mobile'], []]]

# %%
for i in range(2012, 2024):
    YEAR = i
    os.makedirs(f'data/{i}', exist_ok=True)
    for name, jobs, exclude in jobs_to_scrape:
        dfs = []
        for job in jobs:
            print(f'scraping {job}')
            data = get_data(job, YEAR)
            data = process_data(data)
            data = extract_data(data, YEAR)
            df = table_to_dataframe(data)
            for word in exclude:
                df = df[~df['Job'].str.contains(str.upper(word))]
            df['Salary'] = df['Salary'].str.replace(',', '').str.replace('$', '').astype(float)
            dfs.append(df)
        df = pd.concat(dfs)
        df.to_csv(f'data/{i}/{name}.csv', index=False)
        print(f'{name} done')
        print('-------------------')
    print(f'{YEAR} done')
# Out:
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2012 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2013 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2014 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2015 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2016 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2017 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2018 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2019 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2020 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2021 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2022 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# Data Science done
# -------------------
# scraping data ana
# Data Analyst done
# -------------------
# scraping data eng
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# Mobile Developer done
# -------------------
# 2023 done

# %%
# Summary Page
for year in os.listdir('data'):
    records = 0
    for file in os.listdir(f'data/{year}'):
        df = pd.read_csv(f'data/{year}/{file}')
        print(f'{file}: {df.shape[0]} records')
        records += df.shape[0]
    print(f'{year}: {records} records')
    print('-------------------')
# Out:
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 0 records
# Cloud Architect.csv: 0 records
# Cybersecurity Engineer.csv: 0 records
# Data Analyst.csv: 0 records
# Data Architect.csv: 0 records
# Data Engineer.csv: 0 records
# Data Science.csv: 0 records
# Deep Learning.csv: 0 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 0 records
# Front-end Developer.csv: 0 records
# Full-Stack Developer.csv: 0 records
# Graphics.csv: 0 records
# Machine Learning.csv: 0 records
# Mobile Developer.csv: 0 records
# Project Manager.csv: 0 records
# QA Engineer.csv: 0 records
# Security Engineer.csv: 0 records
# Software Architect.csv: 1 records
# 2012: 1 records
# -------------------
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 0 records
# Cloud Architect.csv: 0 records
# Cybersecurity Engineer.csv: 0 records
# Data Analyst.csv: 1 records
# Data Architect.csv: 2 records
# Data Engineer.csv: 3 records
# Data Science.csv: 1 records
# Deep Learning.csv: 0 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 0 records
# Front-end Developer.csv: 0 records
# Full-Stack Developer.csv: 1 records
# Graphics.csv: 2 records
# Machine Learning.csv: 1 records
# Mobile Developer.csv: 1 records
# Project Manager.csv: 0 records
# QA Engineer.csv: 3 records
# Security Engineer.csv: 3 records
# Software Architect.csv: 1 records
# 2013: 19 records
# -------------------
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 0 records
# Cloud Architect.csv: 0 records
# Cybersecurity Engineer.csv: 0 records
# Data Analyst.csv: 4 records
# Data Architect.csv: 1 records
# Data Engineer.csv: 2 records
# Data Science.csv: 3 records
# Deep Learning.csv: 0 records
# DevOps Engineer.csv: 1 records
# Embedded Systems Engineer.csv: 2 records
# Front-end Developer.csv: 1 records
# Full-Stack Developer.csv: 4 records
# Graphics.csv: 1 records
# Machine Learning.csv: 0 records
# Mobile Developer.csv: 0 records
# Project Manager.csv: 0 records
# QA Engineer.csv: 7 records
# Security Engineer.csv: 7 records
# Software Architect.csv: 0 records
# 2014: 33 records
# -------------------
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 0 records
# Cloud Architect.csv: 1 records
# Cybersecurity Engineer.csv: 4 records
# Data Analyst.csv: 148 records
# Data Architect.csv: 35 records
# Data Engineer.csv: 72 records
# Data Science.csv: 127 records
# Deep Learning.csv: 0 records
# DevOps Engineer.csv: 21 records
# Embedded Systems Engineer.csv: 42 records
# Front-end Developer.csv: 49 records
# Full-Stack Developer.csv: 105 records
# Graphics.csv: 53 records
# Machine Learning.csv: 9 records
# Mobile Developer.csv: 52 records
# Project Manager.csv: 39 records
# QA Engineer.csv: 24 records
# Security Engineer.csv: 49 records
# Software Architect.csv: 88 records
# 2015: 918 records
# -------------------
# AR VR.csv: 4 records
# Artifical Intelligence.csv: 17 records
# Cloud Architect.csv: 26 records
# Cybersecurity Engineer.csv: 29 records
# Data Analyst.csv: 2238 records
# Data Architect.csv: 127 records
# Data Engineer.csv: 426 records
# Data Science.csv: 1144 records
# Deep Learning.csv: 4 records
# DevOps Engineer.csv: 298 records
# Embedded Systems Engineer.csv: 355 records
# Front-end Developer.csv: 314 records
# Full-Stack Developer.csv: 922 records
# Graphics.csv: 96 records
# Machine Learning.csv: 45 records
# Mobile Developer.csv: 436 records
# Project Manager.csv: 269 records
# QA Engineer.csv: 146 records
# Security Engineer.csv: 308 records
# Software Architect.csv: 585 records
# 2016: 7789 records
# -------------------
# AR VR.csv: 26 records
# Artifical Intelligence.csv: 27 records
# Cloud Architect.csv: 26 records
# Cybersecurity Engineer.csv: 68 records
# Data Analyst.csv: 1905 records
# Data Architect.csv: 179 records
# Data Engineer.csv: 713 records
# Data Science.csv: 1681 records
# Deep Learning.csv: 16 records
# DevOps Engineer.csv: 726 records
# Embedded Systems Engineer.csv: 398 records
# Front-end Developer.csv: 375 records
# Full-Stack Developer.csv: 976 records
# Graphics.csv: 130 records
# Machine Learning.csv: 140 records
# Mobile Developer.csv: 362 records
# Project Manager.csv: 436 records
# QA Engineer.csv: 149 records
# Security Engineer.csv: 440 records
# Software Architect.csv: 645 records
# 2017: 9418 records
# -------------------
# AR VR.csv: 28 records
# Artifical Intelligence.csv: 75 records
# Cloud Architect.csv: 49 records
# Cybersecurity Engineer.csv: 155 records
# Data Analyst.csv: 2098 records
# Data Architect.csv: 315 records
# Data Engineer.csv: 1226 records
# Data Science.csv: 2807 records
# Deep Learning.csv: 36 records
# DevOps Engineer.csv: 1928 records
# Embedded Systems Engineer.csv: 553 records
# Front-end Developer.csv: 504 records
# Full-Stack Developer.csv: 1197 records
# Graphics.csv: 106 records
# Machine Learning.csv: 303 records
# Mobile Developer.csv: 410 records
# Project Manager.csv: 893 records
# QA Engineer.csv: 180 records
# Security Engineer.csv: 705 records
# Software Architect.csv: 863 records
# 2018: 14431 records
# -------------------
# AR VR.csv: 35 records
# Artifical Intelligence.csv: 156 records
# Cloud Architect.csv: 59 records
# Cybersecurity Engineer.csv: 207 records
# Data Analyst.csv: 2511 records
# Data Architect.csv: 374 records
# Data Engineer.csv: 1975 records
# Data Science.csv: 3906 records
# Deep Learning.csv: 33 records
# DevOps Engineer.csv: 2573 records
# Embedded Systems Engineer.csv: 732 records
# Front-end Developer.csv: 704 records
# Full-Stack Developer.csv: 1662 records
# Graphics.csv: 111 records
# Machine Learning.csv: 585 records
# Mobile Developer.csv: 441 records
# Project Manager.csv: 973 records
# QA Engineer.csv: 131 records
# Security Engineer.csv: 754 records
# Software Architect.csv: 761 records
# 2019: 18683 records
# -------------------
# AR VR.csv: 62 records
# Artifical Intelligence.csv: 146 records
# Cloud Architect.csv: 70 records
# Cybersecurity Engineer.csv: 239 records
# Data Analyst.csv: 2309 records
# Data Architect.csv: 302 records
# Data Engineer.csv: 2960 records
# Data Science.csv: 4347 records
# Deep Learning.csv: 24 records
# DevOps Engineer.csv: 2092 records
# Embedded Systems Engineer.csv: 564 records
# Front-end Developer.csv: 565 records
# Full-Stack Developer.csv: 1368 records
# Graphics.csv: 106 records
# Machine Learning.csv: 742 records
# Mobile Developer.csv: 338 records
# Project Manager.csv: 879 records
# QA Engineer.csv: 2195 records
# Security Engineer.csv: 791 records
# Software Architect.csv: 765 records
# 2020: 20864 records
# -------------------
# AR VR.csv: 70 records
# Artifical Intelligence.csv: 183 records
# Cloud Architect.csv: 109 records
# Cybersecurity Engineer.csv: 244 records
# Data Analyst.csv: 2710 records
# Data Architect.csv: 310 records
# Data Engineer.csv: 4275 records
# Data Science.csv: 5218 records
# Deep Learning.csv: 23 records
# DevOps Engineer.csv: 2419 records
# Embedded Systems Engineer.csv: 607 records
# Front-end Developer.csv: 680 records
# Full-Stack Developer.csv: 1881 records
# Graphics.csv: 238 records
# Machine Learning.csv: 1146 records
# Mobile Developer.csv: 242 records
# Project Manager.csv: 1010 records
# QA Engineer.csv: 2116 records
# Security Engineer.csv: 787 records
# Software Architect.csv: 669 records
# 2021: 24937 records
# -------------------
# AR VR.csv: 66 records
# Artifical Intelligence.csv: 195 records
# Cloud Architect.csv: 104 records
# Cybersecurity Engineer.csv: 310 records
# Data Analyst.csv: 2489 records
# Data Architect.csv: 267 records
# Data Engineer.csv: 5126 records
# Data Science.csv: 5108 records
# Deep Learning.csv: 24 records
# DevOps Engineer.csv: 2258 records
# Embedded Systems Engineer.csv: 514 records
# Front-end Developer.csv: 763 records
# Full-Stack Developer.csv: 1857 records
# Graphics.csv: 291 records
# Machine Learning.csv: 1170 records
# Mobile Developer.csv: 232 records
# Project Manager.csv: 553 records
# QA Engineer.csv: 2028 records
# Security Engineer.csv: 884 records
# Software Architect.csv: 629 records
# 2022: 24868 records
# -------------------
# AR VR.csv: 62 records
# Artifical Intelligence.csv: 216 records
# Cloud Architect.csv: 124 records
# Cybersecurity Engineer.csv: 353 records
# Data Analyst.csv: 2006 records
# Data Architect.csv: 208 records
# Data Engineer.csv: 4062 records
# Data Science.csv: 3720 records
# Deep Learning.csv: 17 records
# DevOps Engineer.csv: 1785 records
# Embedded Systems Engineer.csv: 390 records
# Front-end Developer.csv: 494 records
# Full-Stack Developer.csv: 1286 records
# Graphics.csv: 152 records
# Machine Learning.csv: 896 records
# Mobile Developer.csv: 146 records
# Project Manager.csv: 708 records
# QA Engineer.csv: 1633 records
# Security Engineer.csv: 652 records
# Software Architect.csv: 464 records
# 2023: 19374 records
# -------------------
