# %%
import requests
import pandas as pd
import os
import sys

# %%
# Senior Role String Identifiers
senior_roles = ['senior', 'sr', 'lead','manager','management','principal', 'staff', 'director', 'head', 'chief', 'vp', 'cto', 'cfo', 'cio', 'coo', 'ceo', 'president', 'founder', 'partner', 'executive', 'expert', 'guru']

# Numbered Roles for Seniority
seniority = [ 'III', 'IV', 'V', 'VI', 'VII', 'VIII', 'IX', 'X', 3, 4, 5, 6, 7, 8, 9, 10]
seniority = [str(x) for x in seniority]

# %%
# site https://h1bdata.info/index.php?em=&job=[job]&city=&year=2023
def get_data(job, year):
    url = f'https://h1bdata.info/index.php?em=&job={job}&city=&year={year}'
    response = requests.get(url)
    return response.text

def process_data(data):
    data = data.split('<table border="1" id="myTable" class="tablesorter tablesorter-blue hasStickyHeaders">')[1]
    data = data.split('</table>')[0]
    data = data.split('<tr>')
    data = data[1:]
    data = [x.split('</td>') for x in data]
    data = [[x.split('<td>') for x in y] for y in data]
    data = [[x[1] for x in y if len(x) > 1] for y in data]
    data = [[x.replace('<a href="', '').replace('">', ' ').replace('</a>', '') for x in y] for y in data]
    return data

def extract_data(data, year):
    table = []
    for row in data[1:]:
        try:
            company = row[0][row[0].find(str(year)) + 5:]
            job = row[1][row[1].find(str(year)) + 5:]
            salary = row[2][row[2].find("_blank") + 7:]
            location = row[3][row[3].find(str(year)) + 5:]
            year = year

            # if job is scrum or agile skip the check and append
            if 'scrum' in job.lower() or 'agile' in job.lower() or 'devops' in job.lower():
                table.append([company, job, salary, location, year])
                continue
            
            if any(x in job.lower() for x in senior_roles) or any(x in job for x in seniority):
                continue
            table.append([company, job, salary, location, year])
        except Exception as e:
            print(row)
            continue

    return table

def table_to_dataframe(data):
    df = pd.DataFrame(data, columns=['Company', 'Job', 'Salary', 'Location', 'Year'])
    return df

# %%
jobx = 'data+scientist'
year = 2023
data = get_data(jobx, year)
data = process_data(data)
data = extract_data(data, year)
df = table_to_dataframe(data)
print(df)
# Out:
# []
# []
# []
# []
# []
#                    Company             Job   Salary        Location  Year
# 0       ISTEAM ACADEMY INC  DATA SCIENTIST   56,000  BURLINGTON, MA  2023
# 1     UNIHOME NEW YORK INC  DATA SCIENTIST   57,440        TROY, MI  2023
# 2         LINEAR STATS INC  DATA SCIENTIST   58,000   CHAMPAIGN, IL  2023
# 3         LINEAR STATS INC  DATA SCIENTIST   60,000   CHAMPAIGN, IL  2023
# 4         LINEAR STATS INC  DATA SCIENTIST   60,000   CHAMPAIGN, IL  2023
# ...                    ...             ...      ...             ...   ...
# 2214         BYTEDANCE INC  DATA SCIENTIST  315,000    SAN JOSE, CA  2023
# 2215               USG INC  DATA SCIENTIST  910,000      DULUTH, GA  2023
# 2216               USG INC  DATA SCIENTIST  910,000      DULUTH, GA  2023
# 2217               USG INC  DATA SCIENTIST  910,000      DULUTH, GA  2023
# 2218               USG INC  DATA SCIENTIST  910,000      DULUTH, GA  2023
#
# [2219 rows x 5 columns]

# %%
with open('jobs_to_scrape.txt', 'r') as f:
    jobs = f.readlines()
    jobs = [x.strip() for x in jobs]

jobs_to_scrape = []
for row in jobs:
    data = row.split(':')
    name = data[0]
    print(name)
    data = data[1].split(',')
    exclude = [x[1:] for x in data if x[0] == '-']
    include = [x for x in data if x[0] != '-']
    jobs_to_scrape.append([name, include, exclude])
# Out:
# Machine Learning
# Artifical Intelligence
# Data Science
# Data Analyst
# Data Engineer
# Graphics
# AR VR
# Deep Learning
# Cybersecurity Engineer
# Security Engineer
# Embedded Systems Engineer
# Full-Stack Developer
# Front-end Developer
# DevOps Engineer
# Cloud Architect
# Software Architect
# Data Architect
# Project Manager
# QA Engineer
# Mobile Developer

# %%
jobs_to_scrape
# Out:
# [['Machine Learning', ['machine learnin', 'ml'], []],
#  ['Artifical Intelligence',
#   ['artificial', 'ai'],
#   ['AIR', 'AIRCRAFT', 'AIRLINE', 'AIX', 'AIR QUALITY', 'AIRPORT']],
#  ['Data Science', ['data scien'], []],
#  ['Data Analyst', ['data ana'], []],
#  ['Data Engineer', ['data eng'], []],
#  ['Graphics',
#   ['gpu', 'graphics software engineer', 'graphics hardware engineer'],
#   []],
#  ['AR VR',
#   ['ar ', 'vr ', 'virtual reality', 'augmented'],
#   ['architect',
#    'arc',
#    'art',
#    'ara',
#    'area',
#    'archer',
#    'ariba',
#    'archivist',
#    'ARCHITECH',
#    'ARABIC',
#    'ARCHEOLOGIIST']],
#  ['Deep Learning', ['deep learnin'], []],
#  ['Cybersecurity Engineer', ['cyber'], []],
#  ['Security Engineer', ['security'], []],
#  ['Embedded Systems Engineer', ['embedded'], []],
#  ['Full-Stack Developer', ['full stac', 'web dev'], []],
#  ['Front-end Developer', ['front'], []],
#  ['DevOps Engineer', ['devop'], []],
#  ['Cloud Architect', ['cloud arc'], []],
#  ['Software Architect', ['software arc'], []],
#  ['Data Architect', ['data arc'], []],
#  ['Project Manager', ['scrum ma', 'scrum', 'agile pr'], []],
#  ['QA Engineer', ['testin', 'qa'], []],
#  ['Mobile Developer', ['mobile'], []]]

# %%
for i in range(2015, 2024):
    YEAR = i
    os.makedirs(f'data/{i}', exist_ok=True)
    for name, jobs, exclude in jobs_to_scrape:
        dfs = []
        for job in jobs:
            print(f'scraping {job}')
            data = get_data(job, YEAR)
            data = process_data(data)
            data = extract_data(data, YEAR)
            df = table_to_dataframe(data)
            for word in exclude:
                df = df[~df['Job'].str.contains(str.upper(word))]
            df['Salary'] = df['Salary'].str.replace(',', '').str.replace('$', '').astype(float)
            dfs.append(df)
        df = pd.concat(dfs)
        df.to_csv(f'data/{i}/{name}.csv', index=False)
        print(f'{name} done')
        print('-------------------')
    print(f'{YEAR} done')
# Out:
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# Security Engineer done
# -------------------
# scraping embedded
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# scraping web dev
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# Front-end Developer done
# -------------------
# scraping devop
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# Data Architect done
# -------------------
# scraping scrum ma
# scraping scrum
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# []
# Mobile Developer done
# -------------------
# 2015 done
# scraping machine learnin
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# []
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# scraping scrum
# []
# []
# []
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# []
# []
# []
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2016 done
# scraping machine learnin
# []
# []
# []
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# []
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# scraping scrum
# []
# []
# []
# []
# []
# []
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# []
# []
# []
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2017 done
# scraping machine learnin
# []
# []
# []
# []
# []
# []
# []
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# []
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# []
# []
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# []
# scraping scrum
# []
# []
# []
# []
# []
# []
# []
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# []
# []
# []
# []
# []
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2018 done
# scraping machine learnin
# []
# []
# []
# []
# []
# []
# []
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# []
# scraping graphics hardware engineer
# []
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# []
# []
# []
# []
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# []
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# []
# scraping scrum
# []
# []
# []
# []
# []
# []
# []
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# []
# []
# []
# scraping qa
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2019 done
# scraping machine learnin
# []
# []
# []
# []
# []
# []
# []
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# scraping graphics hardware engineer
# []
# Graphics done
# -------------------
# scraping ar
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# []
# []
# []
# []
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# []
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# []
# scraping scrum
# []
# []
# []
# []
# []
# []
# []
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# []
# []
# scraping qa
# []
# []
# []
# []
# []
# []
# []
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2020 done
# scraping machine learnin
# []
# []
# []
# []
# []
# []
# []
# scraping ml
# []
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# []
# scraping graphics hardware engineer
# []
# []
# []
# []
# Graphics done
# -------------------
# scraping ar
# []
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# []
# []
# []
# []
# []
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# []
# []
# []
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# []
# scraping scrum
# []
# []
# []
# []
# []
# []
# []
# scraping agile pr
# []
# Project Manager done
# -------------------
# scraping testin
# []
# []
# scraping qa
# []
# []
# []
# []
# []
# []
# []
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2021 done
# scraping machine learnin
# []
# []
# []
# []
# []
# []
# []
# scraping ml
# []
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# scraping graphics software engineer
# []
# scraping graphics hardware engineer
# []
# []
# []
# []
# []
# Graphics done
# -------------------
# scraping ar
# []
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# []
# []
# []
# []
# []
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# []
# []
# []
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# []
# scraping scrum
# scraping agile pr
# []
# Project Manager done
# -------------------
# scraping testin
# []
# scraping qa
# []
# []
# []
# []
# []
# []
# []
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# []
# []
# []
# Mobile Developer done
# -------------------
# 2022 done
# scraping machine learnin
# []
# []
# []
# []
# []
# []
# []
# scraping ml
# Machine Learning done
# -------------------
# scraping artificial
# scraping ai
# []
# []
# []
# []
# []
# Artifical Intelligence done
# -------------------
# scraping data scien
# []
# []
# []
# []
# []
# []
# []
# Data Science done
# -------------------
# scraping data ana
# []
# []
# []
# []
# []
# []
# []
# Data Analyst done
# -------------------
# scraping data eng
# []
# []
# []
# []
# []
# []
# []
# Data Engineer done
# -------------------
# scraping gpu
# []
# scraping graphics software engineer
# scraping graphics hardware engineer
# []
# Graphics done
# -------------------
# scraping ar
# []
# scraping vr
# scraping virtual reality
# scraping augmented
# AR VR done
# -------------------
# scraping deep learnin
# Deep Learning done
# -------------------
# scraping cyber
# []
# []
# []
# []
# []
# []
# []
# Cybersecurity Engineer done
# -------------------
# scraping security
# []
# []
# []
# []
# []
# []
# []
# Security Engineer done
# -------------------
# scraping embedded
# []
# []
# []
# []
# []
# []
# []
# Embedded Systems Engineer done
# -------------------
# scraping full stac
# []
# []
# []
# []
# []
# []
# []
# scraping web dev
# []
# []
# []
# []
# []
# []
# Full-Stack Developer done
# -------------------
# scraping front
# []
# []
# []
# []
# []
# []
# []
# Front-end Developer done
# -------------------
# scraping devop
# []
# []
# []
# []
# []
# []
# []
# DevOps Engineer done
# -------------------
# scraping cloud arc
# []
# []
# []
# Cloud Architect done
# -------------------
# scraping software arc
# []
# []
# []
# []
# []
# []
# []
# Software Architect done
# -------------------
# scraping data arc
# []
# []
# []
# []
# []
# []
# Data Architect done
# -------------------
# scraping scrum ma
# []
# []
# []
# []
# []
# []
# []
# scraping scrum
# []
# []
# []
# []
# []
# []
# []
# scraping agile pr
# Project Manager done
# -------------------
# scraping testin
# []
# scraping qa
# []
# []
# []
# []
# []
# []
# []
# QA Engineer done
# -------------------
# scraping mobile
# []
# []
# []
# Mobile Developer done
# -------------------
# 2023 done

# %%
# Summary Page
for year in os.listdir('data'):
    records = 0
    for file in os.listdir(f'data/{year}'):
        df = pd.read_csv(f'data/{year}/{file}')
        print(f'{file}: {df.shape[0]} records')
        records += df.shape[0]
    print(f'{year}: {records} records')
    print('-------------------')
# Out:
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 0 records
# Cloud Architect.csv: 0 records
# Cybersecurity Engineer.csv: 0 records
# Data Analyst.csv: 0 records
# Data Architect.csv: 0 records
# Data Engineer.csv: 0 records
# Data Science.csv: 0 records
# Deep Learning.csv: 0 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 0 records
# Front-end Developer.csv: 0 records
# Full-Stack Developer.csv: 0 records
# Graphics.csv: 0 records
# Machine Learning.csv: 0 records
# Mobile Developer.csv: 0 records
# Project Manager.csv: 0 records
# QA Engineer.csv: 0 records
# Security Engineer.csv: 0 records
# Software Architect.csv: 1 records
# 2012: 1 records
# -------------------
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 0 records
# Cloud Architect.csv: 0 records
# Cybersecurity Engineer.csv: 0 records
# Data Analyst.csv: 1 records
# Data Architect.csv: 2 records
# Data Engineer.csv: 3 records
# Data Science.csv: 1 records
# Deep Learning.csv: 0 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 0 records
# Front-end Developer.csv: 0 records
# Full-Stack Developer.csv: 0 records
# Graphics.csv: 2 records
# Machine Learning.csv: 1 records
# Mobile Developer.csv: 1 records
# Project Manager.csv: 0 records
# QA Engineer.csv: 2 records
# Security Engineer.csv: 2 records
# Software Architect.csv: 0 records
# 2013: 15 records
# -------------------
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 0 records
# Cloud Architect.csv: 0 records
# Cybersecurity Engineer.csv: 0 records
# Data Analyst.csv: 4 records
# Data Architect.csv: 1 records
# Data Engineer.csv: 2 records
# Data Science.csv: 3 records
# Deep Learning.csv: 0 records
# DevOps Engineer.csv: 0 records
# Embedded Systems Engineer.csv: 2 records
# Front-end Developer.csv: 0 records
# Full-Stack Developer.csv: 0 records
# Graphics.csv: 1 records
# Machine Learning.csv: 0 records
# Mobile Developer.csv: 0 records
# Project Manager.csv: 0 records
# QA Engineer.csv: 6 records
# Security Engineer.csv: 4 records
# Software Architect.csv: 0 records
# 2014: 23 records
# -------------------
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 0 records
# Cloud Architect.csv: 1 records
# Cybersecurity Engineer.csv: 3 records
# Data Analyst.csv: 127 records
# Data Architect.csv: 32 records
# Data Engineer.csv: 68 records
# Data Science.csv: 116 records
# Deep Learning.csv: 0 records
# DevOps Engineer.csv: 21 records
# Embedded Systems Engineer.csv: 33 records
# Front-end Developer.csv: 24 records
# Full-Stack Developer.csv: 8 records
# Graphics.csv: 53 records
# Machine Learning.csv: 7 records
# Mobile Developer.csv: 22 records
# Project Manager.csv: 39 records
# QA Engineer.csv: 12 records
# Security Engineer.csv: 41 records
# Software Architect.csv: 87 records
# 2015: 694 records
# -------------------
# AR VR.csv: 0 records
# Artifical Intelligence.csv: 11 records
# Cloud Architect.csv: 26 records
# Cybersecurity Engineer.csv: 22 records
# Data Analyst.csv: 2018 records
# Data Architect.csv: 120 records
# Data Engineer.csv: 394 records
# Data Science.csv: 1086 records
# Deep Learning.csv: 1 records
# DevOps Engineer.csv: 295 records
# Embedded Systems Engineer.csv: 246 records
# Front-end Developer.csv: 112 records
# Full-Stack Developer.csv: 73 records
# Graphics.csv: 96 records
# Machine Learning.csv: 39 records
# Mobile Developer.csv: 186 records
# Project Manager.csv: 269 records
# QA Engineer.csv: 72 records
# Security Engineer.csv: 241 records
# Software Architect.csv: 570 records
# 2016: 5877 records
# -------------------
# AR VR.csv: 7 records
# Artifical Intelligence.csv: 25 records
# Cloud Architect.csv: 26 records
# Cybersecurity Engineer.csv: 59 records
# Data Analyst.csv: 1739 records
# Data Architect.csv: 162 records
# Data Engineer.csv: 668 records
# Data Science.csv: 1590 records
# Deep Learning.csv: 12 records
# DevOps Engineer.csv: 725 records
# Embedded Systems Engineer.csv: 300 records
# Front-end Developer.csv: 141 records
# Full-Stack Developer.csv: 80 records
# Graphics.csv: 128 records
# Machine Learning.csv: 113 records
# Mobile Developer.csv: 182 records
# Project Manager.csv: 436 records
# QA Engineer.csv: 81 records
# Security Engineer.csv: 357 records
# Software Architect.csv: 619 records
# 2017: 7450 records
# -------------------
# AR VR.csv: 8 records
# Artifical Intelligence.csv: 55 records
# Cloud Architect.csv: 48 records
# Cybersecurity Engineer.csv: 116 records
# Data Analyst.csv: 1872 records
# Data Architect.csv: 287 records
# Data Engineer.csv: 1106 records
# Data Science.csv: 2663 records
# Deep Learning.csv: 34 records
# DevOps Engineer.csv: 1926 records
# Embedded Systems Engineer.csv: 419 records
# Front-end Developer.csv: 155 records
# Full-Stack Developer.csv: 159 records
# Graphics.csv: 103 records
# Machine Learning.csv: 268 records
# Mobile Developer.csv: 171 records
# Project Manager.csv: 893 records
# QA Engineer.csv: 108 records
# Security Engineer.csv: 603 records
# Software Architect.csv: 840 records
# 2018: 11834 records
# -------------------
# AR VR.csv: 9 records
# Artifical Intelligence.csv: 120 records
# Cloud Architect.csv: 59 records
# Cybersecurity Engineer.csv: 170 records
# Data Analyst.csv: 2185 records
# Data Architect.csv: 338 records
# Data Engineer.csv: 1813 records
# Data Science.csv: 3639 records
# Deep Learning.csv: 28 records
# DevOps Engineer.csv: 2571 records
# Embedded Systems Engineer.csv: 514 records
# Front-end Developer.csv: 281 records
# Full-Stack Developer.csv: 248 records
# Graphics.csv: 110 records
# Machine Learning.csv: 546 records
# Mobile Developer.csv: 140 records
# Project Manager.csv: 973 records
# QA Engineer.csv: 71 records
# Security Engineer.csv: 621 records
# Software Architect.csv: 739 records
# 2019: 15175 records
# -------------------
# AR VR.csv: 8 records
# Artifical Intelligence.csv: 117 records
# Cloud Architect.csv: 66 records
# Cybersecurity Engineer.csv: 188 records
# Data Analyst.csv: 2045 records
# Data Architect.csv: 271 records
# Data Engineer.csv: 2655 records
# Data Science.csv: 4051 records
# Deep Learning.csv: 21 records
# DevOps Engineer.csv: 2090 records
# Embedded Systems Engineer.csv: 438 records
# Front-end Developer.csv: 307 records
# Full-Stack Developer.csv: 267 records
# Graphics.csv: 105 records
# Machine Learning.csv: 697 records
# Mobile Developer.csv: 114 records
# Project Manager.csv: 879 records
# QA Engineer.csv: 1651 records
# Security Engineer.csv: 650 records
# Software Architect.csv: 735 records
# 2020: 17355 records
# -------------------
# AR VR.csv: 9 records
# Artifical Intelligence.csv: 143 records
# Cloud Architect.csv: 97 records
# Cybersecurity Engineer.csv: 175 records
# Data Analyst.csv: 2364 records
# Data Architect.csv: 272 records
# Data Engineer.csv: 3792 records
# Data Science.csv: 4788 records
# Deep Learning.csv: 15 records
# DevOps Engineer.csv: 2415 records
# Embedded Systems Engineer.csv: 471 records
# Front-end Developer.csv: 378 records
# Full-Stack Developer.csv: 371 records
# Graphics.csv: 234 records
# Machine Learning.csv: 994 records
# Mobile Developer.csv: 101 records
# Project Manager.csv: 1010 records
# QA Engineer.csv: 1552 records
# Security Engineer.csv: 641 records
# Software Architect.csv: 638 records
# 2021: 20460 records
# -------------------
# AR VR.csv: 2 records
# Artifical Intelligence.csv: 127 records
# Cloud Architect.csv: 97 records
# Cybersecurity Engineer.csv: 235 records
# Data Analyst.csv: 2133 records
# Data Architect.csv: 224 records
# Data Engineer.csv: 4497 records
# Data Science.csv: 4552 records
# Deep Learning.csv: 16 records
# DevOps Engineer.csv: 2254 records
# Embedded Systems Engineer.csv: 381 records
# Front-end Developer.csv: 440 records
# Full-Stack Developer.csv: 361 records
# Graphics.csv: 288 records
# Machine Learning.csv: 1028 records
# Mobile Developer.csv: 90 records
# Project Manager.csv: 553 records
# QA Engineer.csv: 1505 records
# Security Engineer.csv: 749 records
# Software Architect.csv: 585 records
# 2022: 20117 records
# -------------------
# AR VR.csv: 4 records
# Artifical Intelligence.csv: 153 records
# Cloud Architect.csv: 123 records
# Cybersecurity Engineer.csv: 246 records
# Data Analyst.csv: 1736 records
# Data Architect.csv: 184 records
# Data Engineer.csv: 3590 records
# Data Science.csv: 3340 records
# Deep Learning.csv: 16 records
# DevOps Engineer.csv: 1784 records
# Embedded Systems Engineer.csv: 300 records
# Front-end Developer.csv: 288 records
# Full-Stack Developer.csv: 316 records
# Graphics.csv: 151 records
# Machine Learning.csv: 781 records
# Mobile Developer.csv: 37 records
# Project Manager.csv: 708 records
# QA Engineer.csv: 1265 records
# Security Engineer.csv: 556 records
# Software Architect.csv: 441 records
# 2023: 16019 records
# -------------------
